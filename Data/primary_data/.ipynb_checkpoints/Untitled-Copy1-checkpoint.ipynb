# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplitlib inline
# Out:
# UsageError: Line magic function `%matplitlib` not found.

# %%
primary = pd.read_csv('primary_results.csv')

# %%
primary.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %%
county = pd.read_csv('county_facts.csv')

# %%
county.tail(8)
# Out:
#        fips          area_name state_abbreviation  PST045214  PST040210  \
# 3187  56031      Platte County                 WY       8799       8667
# 3188  56033    Sheridan County                 WY      30032      29116
# 3189  56035    Sublette County                 WY      10057      10247
# 3190  56037  Sweetwater County                 WY      45010      43806
# 3191  56039       Teton County                 WY      22930      21294
# 3192  56041       Uinta County                 WY      20904      21118
# 3193  56043    Washakie County                 WY       8322       8533
# 3194  56045      Weston County                 WY       7201       7208
#
#       PST120214  POP010210  AGE135214  AGE295214  AGE775214    ...      \
# 3187        1.5       8667        4.9       20.4       22.7    ...
# 3188        3.1      29116        5.6       21.6       18.3    ...
# 3189       -1.9      10247        5.8       24.0       12.6    ...
# ...

# %%
county.head()
# Out:
#    fips       area_name state_abbreviation  PST045214  PST040210  PST120214  \
# 0     0   United States                NaN  318857056  308758105        3.3
# 1  1000         Alabama                NaN    4849377    4780127        1.4
# 2  1001  Autauga County                 AL      55395      54571        1.5
# 3  1003  Baldwin County                 AL     200111     182265        9.8
# 4  1005  Barbour County                 AL      26887      27457       -2.1
#
#    POP010210  AGE135214  AGE295214  AGE775214    ...      SBO415207  \
# 0  308745538        6.2       23.1       14.5    ...            8.3
# 1    4779736        6.1       22.8       15.3    ...            1.2
# 2      54571        6.0       25.2       13.8    ...            0.7
# 3     182265        5.6       22.2       18.7    ...            1.3
# 4      27457        5.7       21.2       16.5    ...            0.0
#
#    SBO015207   MAN450207   WTN220207   RTN130207  RTN131207  AFN120207  \
# ...

# %%
county_dict = pd.read_csv('county_facts_dictionary.csv')

# %%
county_dict
# Out:
#                                                    description
# column_name
# PST045214                            Population, 2014 estimate
# PST040210            Population, 2010 (April 1) estimates base
# PST120214    Population, percent change - April 1, 2010 to ...
# POP010210                                     Population, 2010
# AGE135214                 Persons under 5 years, percent, 2014
# AGE295214                Persons under 18 years, percent, 2014
# AGE775214             Persons 65 years and over, percent, 2014
# SEX255214                        Female persons, percent, 2014
# RHI125214                           White alone, percent, 2014
# RHI225214       Black or African American alone, percent, 2014
# RHI325214    American Indian and Alaska Native alone, perce...
# RHI425214                           Asian alone, percent, 2014
# RHI525214    Native Hawaiian and Other Pacific Islander alo...
# RHI625214                     Two or More Races, percent, 2014
# ...

# %%
df = pd.merge(primary, county, how='left', on='fips')

# %%
df.head()
# Out:
#      state state_abbreviation_x   county  fips     party        candidate  \
# 0  Alabama                   AL  Autauga  1001  Democrat   Bernie Sanders
# 1  Alabama                   AL  Autauga  1001  Democrat  Hillary Clinton
# 2  Alabama                   AL  Baldwin  1003  Democrat   Bernie Sanders
# 3  Alabama                   AL  Baldwin  1003  Democrat  Hillary Clinton
# 4  Alabama                   AL  Barbour  1005  Democrat   Bernie Sanders
#
#    votes  fraction_votes       area_name state_abbreviation_y    ...      \
# 0    544           0.182  Autauga County                   AL    ...
# 1   2387           0.800  Autauga County                   AL    ...
# 2   2694           0.329  Baldwin County                   AL    ...
# 3   5290           0.647  Baldwin County                   AL    ...
# 4    222           0.078  Barbour County                   AL    ...
#
#    SBO415207  SBO015207  MAN450207  WTN220207  RTN130207  RTN131207  \
# ...

# %%
df.drop(columns='state_abbreviation_y', inplace =True)

# %%
df.head()
# Out:
#      state state_abbreviation_x   county  fips     party        candidate  \
# 0  Alabama                   AL  Autauga  1001  Democrat   Bernie Sanders
# 1  Alabama                   AL  Autauga  1001  Democrat  Hillary Clinton
# 2  Alabama                   AL  Baldwin  1003  Democrat   Bernie Sanders
# 3  Alabama                   AL  Baldwin  1003  Democrat  Hillary Clinton
# 4  Alabama                   AL  Barbour  1005  Democrat   Bernie Sanders
#
#    votes  fraction_votes       area_name  PST045214    ...      SBO415207  \
# 0    544           0.182  Autauga County    55395.0    ...            0.7
# 1   2387           0.800  Autauga County    55395.0    ...            0.7
# 2   2694           0.329  Baldwin County   200111.0    ...            1.3
# 3   5290           0.647  Baldwin County   200111.0    ...            1.3
# 4    222           0.078  Barbour County    26887.0    ...            0.0
#
#    SBO015207  MAN450207  WTN220207  RTN130207  RTN131207  AFN120207  \
# ...

# %%
df.rename({'state_abbreviation_x': 'state_abbreviation'}, axis=1, inplace=True)

# %%
df
# Out:
#          state state_abbreviation                county      fips       party  \
# 0      Alabama                 AL               Autauga      1001    Democrat
# 1      Alabama                 AL               Autauga      1001    Democrat
# 2      Alabama                 AL               Baldwin      1003    Democrat
# 3      Alabama                 AL               Baldwin      1003    Democrat
# 4      Alabama                 AL               Barbour      1005    Democrat
# 5      Alabama                 AL               Barbour      1005    Democrat
# 6      Alabama                 AL                  Bibb      1007    Democrat
# 7      Alabama                 AL                  Bibb      1007    Democrat
# 8      Alabama                 AL                Blount      1009    Democrat
# 9      Alabama                 AL                Blount      1009    Democrat
# 10     Alabama                 AL               Bullock      1011    Democrat
# ...

# %%
pd.__version__
# Out:
# u'0.21.0'

# %%
county_dict.set_index('column_name', inplace=True)

# %%
county_dict.loc['PST045214']
# Out:
# description    Population, 2014 estimate
# Name: PST045214, dtype: object

# %%
df[df['fips'].isnull()].head()
# Out:
#                state state_abbreviation    county fips     party  \
# 14587  New Hampshire                 NH   Belknap  NaN  Democrat
# 14588  New Hampshire                 NH   Belknap  NaN  Democrat
# 14589  New Hampshire                 NH   Carroll  NaN  Democrat
# 14590  New Hampshire                 NH   Carroll  NaN  Democrat
# 14591  New Hampshire                 NH  Cheshire  NaN  Democrat
#
#              candidate  votes  fraction_votes area_name  PST045214    ...      \
# 14587   Bernie Sanders   5990        0.631857       NaN        NaN    ...
# 14588  Hillary Clinton   3490        0.368143       NaN        NaN    ...
# 14589   Bernie Sanders   5655        0.636466       NaN        NaN    ...
# 14590  Hillary Clinton   3230        0.363534       NaN        NaN    ...
# 14591   Bernie Sanders  12471        0.707093       NaN        NaN    ...
#
#        SBO415207  SBO015207  MAN450207  WTN220207  RTN130207  RTN131207  \
# ...

# %%
df.dropna(subset=['fips'], inplace=True)

# %%
df[df['fips'].isnull()].head()
# Out:
# Empty DataFrame
# Columns: [state, state_abbreviation, county, fips, party, candidate, votes, fraction_votes, area_name, PST045214, PST040210, PST120214, POP010210, AGE135214, AGE295214, AGE775214, SEX255214, RHI125214, RHI225214, RHI325214, RHI425214, RHI525214, RHI625214, RHI725214, RHI825214, POP715213, POP645213, POP815213, EDU635213, EDU685213, VET605213, LFE305213, HSG010214, HSG445213, HSG096213, HSG495213, HSD410213, HSD310213, INC910213, INC110213, PVY020213, BZA010213, BZA110213, BZA115213, NES010213, SBO001207, SBO315207, SBO115207, SBO215207, SBO515207, SBO415207, SBO015207, MAN450207, WTN220207, RTN130207, RTN131207, AFN120207, BPS030214, LND110210, POP060210]
# Index: []
#
# [0 rows x 60 columns]

# %%
df
# Out:
#          state state_abbreviation                county      fips       party  \
# 0      Alabama                 AL               Autauga      1001    Democrat
# 1      Alabama                 AL               Autauga      1001    Democrat
# 2      Alabama                 AL               Baldwin      1003    Democrat
# 3      Alabama                 AL               Baldwin      1003    Democrat
# 4      Alabama                 AL               Barbour      1005    Democrat
# 5      Alabama                 AL               Barbour      1005    Democrat
# 6      Alabama                 AL                  Bibb      1007    Democrat
# 7      Alabama                 AL                  Bibb      1007    Democrat
# 8      Alabama                 AL                Blount      1009    Democrat
# 9      Alabama                 AL                Blount      1009    Democrat
# 10     Alabama                 AL               Bullock      1011    Democrat
# ...

# %%
county_dict.loc['MAN450207']
# Out:
# description    Manufacturers shipments, 2007 ($1,000)
# Name: MAN450207, dtype: object

# %%
percent = (df['votes'].sum() *100) / (df[])
# Out:
# 56233221

# %%
votes_by_county = df.groupby('county').agg({'votes': 'sum', 'PST045214': 'max'}).dropna()

# %%
votes_by_county.head()
# Out:
#            votes  PST045214
# county
# Abbeville   5480    24965.0
# Acadia      6629    62486.0
# Accomack    6750    33021.0
# Ada        57726   426236.0
# Adair      12570    25602.0

# %%
votes_by_county.rename({'PST045214': 'population'}, axis=1, inplace=True)

# %%
votes_by_county.head()
# Out:
#            votes  population
# county
# Abbeville   5480     24965.0
# Acadia      6629     62486.0
# Accomack    6750     33021.0
# Ada        57726    426236.0
# Adair      12570     25602.0

# %%
percent = (votes_by_county['votes']) / (votes_by_county['population']) * 100

# %%
percent.head()
# Out:
# county
# Abbeville    21.950731
# Acadia       10.608776
# Accomack     20.441537
# Ada          13.543201
# Adair        49.097727
# dtype: float64

# %%
pc = pd.DataFrame(percent)

# %%
pc.head()
# Out:
#                    0
# county
# Abbeville  21.950731
# Acadia     10.608776
# Accomack   20.441537
# Ada        13.543201
# Adair      49.097727

# %%
pc.rename({0: 'percent'}, axis=1, inplace=True)

# %%
pc.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-150-cc888825d6f7> in <module>()
# ----> 1 pc.loc[pc['percent']]
#
# c:\python27\lib\site-packages\pandas\core\indexing.pyc in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# c:\python27\lib\site-packages\pandas\core\indexing.pyc in _getitem_axis(self, key, axis)
#    1614                     raise ValueError('Cannot index with multidimensional key')
#    1615
# -> 1616                 return self._getitem_iterable(key, axis=axis)
#    1617
#    1618             # nested tuple slicing
#
# c:\python27\lib\site-packages\pandas\core\indexing.pyc in _getitem_iterable(self, key, axis)
#    1113
# ...
